# %%
import cv2

img = cv2.imread("image.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

pixel_1 = img[0][0]
print(pixel_1)

import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.imshow(img)
plt.show()
# Out:
# [14  4  8]

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(img)
# Out:
# [[ 6  7  7 ... 28 31 30]
#  [ 9  8  7 ... 29 30 29]
#  [10  9  8 ... 30 28 27]
#  ...
#  [15 15 16 ... 21 28 31]
#  [14 14 14 ... 22 24 27]
#  [14 14 14 ... 30 29 31]]

# %%
import numpy as np

img_flatted = np.ndarray.flatten(img)
print(img_flatted.shape)

for i in range(20):
    if(i%3 == 0):
        print(img_flatted[i])
# Out:
# (1846320,)
# 14
# 14
# 14
# 15
# 14
# 14
# 13

# %%
print(img[0:10, 0:10])
# Out:
# [[[14  4  8]
#   [14  5  9]
#   [14  5  9]
#   [15  6  6]
#   [14  7  4]
#   [14  8  4]
#   [13  9  6]
#   [13  8 10]
#   [15  7 14]
#   [19 10 19]]
#
#  [[16  7 10]
#   [15  6 10]
#   [14  5  9]
#   [15  6  5]
#   [15  7  4]
#   [15  8  4]
#   [14  9  5]
#   [14  8  9]
#   [16  8 14]
#   [19  9 18]]
#
#  [[17  8 11]
#   [16  7 11]
#   [15  6 10]
#   [16  6  8]
#   [16  6  6]
#   [16  7  4]
#   [16  8  5]
#   [16  7  8]
#   [16  8 11]
#   [16  6 14]]
#
#  [[18  9 12]
#   [18  7 12]
#   [17  6 11]
#   [18  6 11]
#   [18  7  9]
#   [18  7  7]
#   [17  7  7]
#   [17  8  7]
#   [18  8  9]
#   [18  8 11]]
#
#  [[17  8 11]
#   [18  7 12]
#   [19  6 13]
#   [20  6 14]
#   [20  6 14]
#   [20  7 11]
#   [18  9  9]
#   [18  9  7]
#   [18  9  6]
#   [18  8  8]]
#
#  [[16  7 10]
#   [18  7 11]
#   [20  6 12]
#   [20  6 14]
#   [21  7 16]
#   [20  8 14]
#   [18  9 10]
#   [18  9  7]
#   [19 11  7]
#   [20 10 10]]
#
#  [[15  6  9]
#   [17  7 10]
#   [19  7 11]
#   [20  7 14]
#   [20  7 16]
#   [19  8 16]
#   [17  9 12]
#   [19 10  8]
#   [19 11  7]
#   [19  9  9]]
#
#  [[15  6  9]
#   [16  7  9]
#   [18  9 11]
#   [22 10 17]
#   [22 11 19]
#   [22 12 20]
#   [20 12 15]
#   [19 10  8]
#   [18 12  7]
#   [23 16 14]]
#
#  [[15  5  8]
#   [16  6  8]
#   [17  8  9]
#   [19  9 15]
#   [21 11 19]
#   [20 12 19]
#   [19 11 14]
#   [18 11  9]
#   [18 11  8]
#   [24 17 15]]
#
#  [[15  5  8]
#   [14  5  7]
#   [16  7  8]
#   [17  8 12]
#   [18 10 16]
#   [18 10 17]
#   [18 10 13]
#   [19 10  9]
#   [20 10 10]
#   [29 20 19]]]

# %%
w, h, c = img.shape
print(w, h)
print(img[100:110])
# Out:
# 628 980
# [[[255 253 251]
#   [254 254 253]
#   [253 255 254]
#   ...
#   [ 85  55  47]
#   [ 86  56  48]
#   [ 85  55  46]]
#
#  [[255 253 250]
#   [255 254 250]
#   [254 255 250]
#   ...
#   [ 87  57  49]
#   [ 87  57  49]
#   [ 86  56  47]]
#
#  [[255 253 250]
#   [255 253 250]
#   [255 254 250]
#   ...
#   [ 89  58  51]
#   [ 89  58  51]
#   [ 88  57  49]]
#
#  ...
#
#  [[255 254 252]
#   [254 254 252]
#   [254 254 252]
#   ...
#   [ 89  61  53]
#   [ 91  63  55]
#   [ 89  60  52]]
#
#  [[255 254 252]
#   [254 254 253]
#   [254 254 253]
#   ...
#   [ 90  61  54]
#   [ 92  64  56]
#   [ 89  60  52]]
#
#  [[255 254 252]
#   [254 254 253]
#   [254 254 254]
#   ...
#   [ 91  62  54]
#   [ 92  64  56]
#   [ 89  61  53]]]
